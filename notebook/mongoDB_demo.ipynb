# %%
import pandas as pd
import pymongo

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
data   = df.to_dict(orient = "records")

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://faizan20313_db_user:ENSo6HGuhsfm5eKL@project1cluster.exv8gqd.mongodb.net/?appName=project1Cluster"

# %%
## client
client = pymongo.MongoClient(CONNECTION_URL)

## data base 
data_base = client[DB_NAME]

# %%
## collection is like table
collection = data_base[COLLECTION_NAME]

# %% [markdown]
# ### Uploading inserting data to Mongo DB

# %%
rec = collection.insert_many(data)
# data_base.drop_collection(COLLECTION_NAME)

# %%
# Load back data from mongodb

df = pd.DataFrame(list(collection.find()))
df.head(2)
# Out:
#                         _id  id Gender  Age  Driving_License  Region_Code  \
# 0  6932adee02a846b75bacf4f2   1   Male   44                1         28.0
# 1  6932adee02a846b75bacf4f3   2   Male   76                1          3.0
#
#    Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  \
# 0                   0   > 2 Years            Yes         40454.0
# 1                   0    1-2 Year             No         33536.0
#
#    Policy_Sales_Channel  Vintage  Response
# 0                  26.0      217         1
# 1                  26.0      183         0

# %%
df
# Out:
#                              _id      id  Gender  Age  Driving_License  \
# 0       6932adee02a846b75bacf4f2       1    Male   44                1
# 1       6932adee02a846b75bacf4f3       2    Male   76                1
# 2       6932adee02a846b75bacf4f4       3    Male   47                1
# 3       6932adee02a846b75bacf4f5       4    Male   21                1
# 4       6932adee02a846b75bacf4f6       5  Female   29                1
# ...                          ...     ...     ...  ...              ...
# 481104  693528f33b529d9777e1613d   99996  Female   23                1
# 481105  693528f33b529d9777e1613e   99997    Male   54                1
# 481106  693528f33b529d9777e1613f   99998  Female   26                1
# 481107  693528f33b529d9777e16140   99999    Male   25                1
# 481108  693528f33b529d9777e16141  100000    Male   22                1
#
#         Region_Code  Previously_Insured Vehicle_Age Vehicle_Damage  \
# ...
